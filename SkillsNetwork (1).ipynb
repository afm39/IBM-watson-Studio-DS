# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ana Fernández-Mariñas**
#
# Data Scientist

# %% [markdown]
# I'm interested in data science because I like programing, AI, maths and tables. I found all this together in data science. en cursiva

# %% [markdown]
# ### I print a sort text and the year that was written.

# %%
print("Hello world, I wrote this in the year...")
year=2022
year
# Out:
# Hello world, I wrote this in the year...
# 2022

# %% [markdown]
# **horizontal rule**
#
# ---
#
# **bulleted list**
#
# + text 1
# + text 2
# + text 3
#     * sub text 3.1
#     * sub text 3.2
#
# ---
#
# **numbered list**
# 1. text 1
# 2. text 2
# 3. text 3
#     1. sub text 3.1
#     2. sub text 3.2
#
# ---
#
# **tables**
#
# | Number | Divided | Result  |
# | ---|---| ---|
# | 10 | 5 | 2 |
# | 8 | 2 | 4 |
# | 25 | 5 | 5 |
#
# ---
#
# **hyperlinks:**
# https://i.blogs.es/ceda9c/dalle/450_1000.jpg
#
# ---
#
# If you open the link you can see this **imagen**
# ![](https://i.blogs.es/ceda9c/dalle/450_1000.jpg)
#
# ---
#
# ```code/syntax highlighting```
#
# ---
#
# > This is a blocked quotes
#
# ---
#
# **strikethrough** ~~Scratch this.~~
#
# ---
